# %%
# Q1 What is Object-Oriented Programming (OOP)?
#  Object-Oriented Programming (OOP) in Python is a programming method where code is organized into classes and objects. 
#  It allows you to bundle data (variables) and behaviour (functions) together inside a class.
#  Python uses OOP to make programs more modular, reusable, flexible, and easier to maintain.

# %%
 # Q2. What is a class in OOP?
 # A class in Object-Oriented Programming (OOP) is a blueprint or template used to create objects.
 # It defines the data (attributes) and the functions (methods) that the objects created from the class will have.
 # In Python, a class is created using the class keyword.

# %%
# Q3. What is an object in OOP?

# An object in Object-Oriented Programming (OOP) is a real instance of a class. 
# It is created from a class and has its own data (attributes) and behaviour (methods)

# %%
# Q4. What is the difference between abstraction and encapsulation?
# Difference Between Abstraction and Encapsulation 

# Abstraction:- 
#             Abstraction means hiding complex details and showing only the essential features to the user.
#             It helps in reducing complexity.
#             In Python, abstraction is done using abstract classes and abstract methods.
# Encapsulation:-
#                 Encapsulation means wrapping data and methods together inside a class.
#                 It helps in protecting data from direct access.
#                 In Python, encapsulation is done using private (__) and protected (_) variables.

# In short
#         Abstraction = Hide details
#         Encapsulation = Hide data

# %%
# Q5. What are dunder methods in Python?
# Dunder methods (short for Double UNDERscore methods) are special built-in methods in Python whose names start and end with two underscores 
#     (e.g., __init__, __str__, __add__).
# They are also called magic methods because Python automatically calls them to perform certain operations

# %%
# Q6. Explain the concept of inheritance in OOP?
# Inheritance in Object-Oriented Programming (OOP) is a feature that allows one class (called the child/subclass)
# to receive or “inherit” the properties and methods of another class (called the parent/superclass).
# It helps in code reusability, avoids repetition, and allows us to build new classes on top of existing ones.

# %%
# Q7. What is polymorphism in OOP?
# Polymorphism in Object-Oriented Programming means one name, many forms.
# It allows the same function or method to behave differently depending on the object or the situation.
# This makes programs more flexible and easier to extend.

# %%
# Q8. How is encapsulation achieved in Python?
# Encapsulation in Python is achieved by restricting direct access to data using access modifiers.
# Python uses private (__), protected (_), and public variables to control how data can be accessed from outside the class.

# %%
# Q9. What is a constructor in Python?

# A constructor in Python is a special method named __init__() that is automatically called when an object is created.
# Its main job is to initialize the object’s variables and set up the initial state of the object.

# %%
# Q10. What are class and static methods in Python?

# 1. Class Method

# A class method is a method that works with the class itself, not with a specific object.
# It uses @classmethod and takes cls as the first parameter.
# Class methods can access or modify class-level variables.

# 2. Static Method

# A static method is a method that does not depend on the class or object.
# It uses @staticmethod and does not take self or cls as a parameter.
# Used for utility/helper functions inside a class.

# %%
# Q11. What is method overloading in Python?
# Method overloading means having multiple methods with the same name but different parameters.
# Python does not support true method overloading like Java or C++,
# but we can achieve it using default arguments or *args so that the same method can handle different numbers of inputs.

# %%
# Q12. What is method overriding in OOP?

# Method overriding in OOP happens when a child class defines a method with the same name and same parameters as a method in its parent class, 
# but provides a new (modified) implementation.
# It is mainly used to achieve runtime polymorphism and allows the child class to change or customize the parent class behavior.

# %%
# Q13. What is a property decorator in Python?

# A property decorator (@property) in Python is used to convert a method into an attribute, so you can access it without parentheses.
# It helps in encapsulation, because you can control how a variable is read, modified, or deleted while still using simple attribute syntax.

# %%
# Q14. Why is polymorphism important in OOP?

# Polymorphism is important in OOP because it allows the same function or method to work differently based on the object.
# This makes programs flexible, reusable, and easier to maintain.
# With polymorphism, you can write one common interface that works for many different classes, reducing code duplication.

# %%
# Q15. What is an abstract class in Python?

# An abstract class in Python is a class that is meant to be inherited, not used to create objects directly.
# It contains abstract methods—methods that have a name but no body.
# Abstract classes define a common template for all child classes and ensure that subclasses provide their own implementation of certain methods.

# Python supports abstract classes through the ABC (Abstract Base Class) module and the @abstractmethod decorator.

# %%
# Q16. What are the advantages of OOP?
# Object-Oriented Programming (OOP) provides several benefits that make code easier to write, manage, and reuse.

# Key Advantages

# 1. Modularity – Code is divided into classes and objects, making programs easier to understand and manage.
# 2. Reusability – Features of existing classes can be reused through inheritance, reducing code repetition.
# 3. Flexibility – Polymorphism allows the same function or method to work in different ways.
# 4. Data Security – Encapsulation protects data by restricting direct access.
# 5. Easy Maintenance – Changes in one part of the program do not affect other parts easily.
# 6. Better Organization – Real-world problems can be represented using objects, making design more natural.

# %%
# Q17. What is the difference between a class variable and an instance variable?

# Difference between a class variable and an instance variable

# Class Variable
# A class variable is shared by all objects of the class.
# It belongs to the class, not to any one object.
# Changing it affects every object of that class.

# Instance Variable
# An instance variable is created inside the constructor (__init__).
# It is unique for each object.
# Changing it affects only that particular object.

# %% [raw]
# Q18. What is multiple inheritance in Python?
#
# Multiple inheritance in Python means that a child class can inherit from more than one parent class at the same time.
# This allows the child class to use the properties and methods of all its parent classes, making it more flexible.

# %% [raw]
# Q19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python ?
#
# purpose of __str__ and __repr__ methods in Python
#
# __str__() Method
# The __str__ method is used to return a user-friendly or readable string representation of an object.
# It is called when you use print() or str(object).
# Purpose: To make the output easy to understand.
#
# __repr__() Method
# The __repr__ method returns a developer-friendly or unambiguous string representation of an object.
# It is called when you use repr(object) or when the object appears in the Python shell.
# Purpose: To show a detailed representation that can help in debugging.

# %% [raw]
# Q20. What is the significance of the super() function in Python?
#
# The super() function in Python is used to call methods of the parent class from within a child class.
# It helps in reusing parent class code, avoids writing duplicate code, and is especially important in inheritance and method overriding.
#
# Why is super() important?
#
# Allows the child class to access parent class methods.
# Helps in initializing parent class attributes inside the child class.
# Supports multiple inheritance by following the MRO (Method Resolution Order).
# Makes code cleaner and easier to maintain.

# %% [raw]
# Q21. What is the significance of the __del__ method in Python?
#
# The __del__ method in Python is a destructor.
# It is automatically called when an object is about to be destroyed or when its memory is being released.
# Its main purpose is to clean up resources, such as closing files, releasing connections, or freeing memory before the object is removed.

# %% [raw]
# Q22. What is the difference between @staticmethod and @classmethod in Python?
#
# Difference between @staticmethod and @classmethod in Python
#
# @staticmethod
# A static method does not use self or cls.
# It works like a normal function inside a class.
# It cannot access or modify the class or object data.
# Used for utility/helper functions.
#
# @classmethod
# A class method uses cls as its first parameter.
# It can access and modify class variables.
# It works on the class as a whole, not on individual objects.
# Used to create alternate constructors or modify class-level data.

# %% [raw]
# Q23. How does polymorphism work in Python with inheritance?
#
# Polymorphism with inheritance means that a child class can provide a different implementation of a method that already exists in the parent class.
# When an object of the child class is used, Python automatically calls the overridden method, even if the reference is of the parent type.
# This allows the same method name to behave differently depending on the object.
#
# How it works
#
# Parent class defines a method.
# Child class overrides that method with a new version.
# Python chooses the method based on the object, not the reference.

# %% [raw]
# Q24. What is method chaining in Python OOP?
#
# Method chaining in Python means calling multiple methods on the same object in a single line, one after another.
# This is possible when each method returns the object itself (usually self), allowing the next method to be called immediately.

# %% [raw]
# Q25. What is the purpose of the __call__ method in Python?
#
# The __call__ method allows an object to be called like a function.
# If a class defines __call__, then its object can be used with parentheses as if it were a function, and the code inside __call__ will run.
#
# Why is it useful?
# Makes objects behave like functions
# Helps in creating callable objects, calculators, counters, wrappers, etc.
# Useful in OOP design, decorators, and advanced programming

# %%
#Q1. Create a parent class Animal with a method speak() that prints a generic message.
#Create a child class Dog that overrides the speak() method to print "Bark!".
    
class Animal:
    def speak(self):
        print("The animal makes a sound.")

class Dog(Animal):
    def speak(self):
        print("Bark!")

a = Animal()
d = Dog()

a.speak()   
d.speak()
# Out:
# The animal makes a sound.
# Bark!

# %%
#Q2. Write a program to create an abstract class Shape with a method area().
#Derive classes Circle and Rectangle from it and implement the area() method in both.


from abc import ABC, abstractmethod


class Shape(ABC):

    @abstractmethod
    def area(self):
        pass


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius


class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


c = Circle(5)
r = Rectangle(10, 4)

print("Area of Circle:", c.area())
print("Area of Rectangle:", r.area())
# Out:
# Area of Circle: 78.5
# Area of Rectangle: 40

# %%
#Q3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type.
 #   Derive a class Car and further derive a class ElectricCar that adds a battery attribute.


class Vehicle:
    def __init__(self, type):
        self.type = type


class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery


e = ElectricCar("Four Wheeler", "Tesla", "75 kWh")

print("Type:", e.type)
print("Brand:", e.brand)
print("Battery:", e.battery)
# Out:
# Type: Four Wheeler
# Brand: Tesla
# Battery: 75 kWh

# %%
#Q4. Demonstrate polymorphism by creating a base class Bird with a method fly(). 
 #   Create two derived classes Sparrow and Penguin that override the fly() method.

class Bird:
    def fly(self):
        print("Bird is flying")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow can fly")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly")

b1 = Sparrow()
b2 = Penguin()

b1.fly()
b2.fly()
# Out:
# Sparrow can fly
# Penguin cannot fly

# %%
#Q5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
#balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self, balance):
        self.__balance = balance   # private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount

    def withdraw(self, amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount

    def check_balance(self):
        return self.__balance


acc = BankAccount(1000)

acc.deposit(500)
acc.withdraw(300)

print("Balance:", acc.check_balance())
# Out:
# Balance: 1200

# %%
#Q6. Demonstrate runtime polymorphism using a method play() in a base class Instrument.
 #   Derive classes Guitar and Piano that implement their own version of play().


class Instrument:
    def play(self):
        print("Instrument is playing")

class Guitar(Instrument):
    def play(self):
        print("Guitar is playing music")

class Piano(Instrument):
    def play(self):
        print("Piano is playing melody")

i1 = Guitar()
i2 = Piano()

i1.play()
i2.play()
# Out:
# Guitar is playing music
# Piano is playing melody

# %%
#Q7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
#method subtract_numbers() to subtract two numbers.

class MathOperations:

    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b


print("Addition:", MathOperations.add_numbers(10, 5))
print("Subtraction:", MathOperations.subtract_numbers(10, 5))
# Out:
# Addition: 15
# Subtraction: 5

# %%
#Q8. Implement a class Person with a class method to count the total number of persons created.

class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count


p1 = Person("Rohit")
p2 = Person("Aman")
p3 = Person("Neha")

print("Total persons created:", Person.total_persons())
# Out:
# Total persons created: 3

# %%
#Q9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
#fraction as "numerator/denominator".


class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


f = Fraction(3, 4)
print(f)
# Out:
# 3/4

# %%
#Q10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"


v1 = Vector(2, 3)
v2 = Vector(4, 1)

v3 = v1 + v2
print(v3)
# Out:
# Vector(6, 4)

# %%
#Q11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
#{name} and I am {age} years old."


class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("Rohit", 24)
p.greet()
# Out:
# Hello, my name is Rohit and I am 24 years old.

# %%
#Q12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
#the average of the grades.

class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

s = Student("Rohit", [85, 90, 78, 92])
print("Average Grade:", s.average_grade())
# Out:
# Average Grade: 86.25

# %%
#Q13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


r = Rectangle()
r.set_dimensions(10, 5)
print("Area:", r.area())
# Out:
# Area: 50

# %%
#Q14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
#and hourly rate. Create a derived class Manager that adds a bonus to the salary


class Employee:
    def calculate_salary(self, hours_worked, hourly_rate):
        return hours_worked * hourly_rate


class Manager(Employee):
    def calculate_salary(self, hours_worked, hourly_rate, bonus):
        base_salary = super().calculate_salary(hours_worked, hourly_rate)
        return base_salary + bonus



emp = Employee()
print("Employee Salary:", emp.calculate_salary(40, 200))

mgr = Manager()
print("Manager Salary:", mgr.calculate_salary(40, 200, 5000))
# Out:
# Employee Salary: 8000
# Manager Salary: 13000

# %%
#15. Create a class Product with attributes name, price, and quantity.
 #   Implement a method total_price() that calculates the total price of the product


class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

\
p = Product("Laptop", 50000, 2)
print("Total Price:", p.total_price())
# Out:
# Total Price: 100000

# %%
#Q16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
#implement the sound() method.


from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass


class Cow(Animal):
    def sound(self):
        return "Cow says Moo"


class Sheep(Animal):
    def sound(self):
        return "Sheep says Baa"


cow = Cow()
sheep = Sheep()

print(cow.sound())
print(sheep.sound())
# Out:
# Cow says Moo
# Sheep says Baa

# %%
#Q17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
#returns a formatted string with the book's details

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year: {self.year_published}"

b = Book("The Alchemist", "Paulo Coelho", 1988)
print(b.get_book_info())
# Out:
# Title: The Alchemist, Author: Paulo Coelho, Year: 1988

# %%
#Q18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
#attribute number_of_rooms.


class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

m = Mansion("Delhi, India", 50000000, 12)
print(m.address, m.price, m.number_of_rooms)
# Out:
# Delhi, India 50000000 12
